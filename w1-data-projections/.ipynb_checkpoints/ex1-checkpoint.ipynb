# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import pandas as pd

import matplotlib.image as mpimg

# %% [markdown]
# # 1 Scatter plots

# %%
# Read data
expData = pd.read_csv('expDat.txt')
expData.describe()
# Out:
#        Unnamed: 0          V1          V2          V3          V4          V5  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    50.500000    4.810000    4.840000    5.360000    5.420000    4.880000
# std     29.011492    3.991645    3.719237    4.265246    4.264441    4.013311
# min      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     25.750000    2.000000    2.000000    2.000000    2.000000    2.000000
# 50%     50.500000    4.000000    4.000000    4.000000    4.000000    3.500000
# 75%     75.250000    7.000000    7.000000    7.000000    7.250000    8.000000
# max    100.000000   17.000000   17.000000   19.000000   18.000000   17.000000
#
#                V6         V7          V8         V9     ...             V11  \
# count  100.000000  100.00000  100.000000  100.00000     ...      100.000000
# mean     5.160000    4.99000    5.040000    4.65000     ...        5.030000
# std      3.759755    3.87297    3.795053    3.82542     ...        4.312198
# min      0.000000    0.00000    0.000000    0.00000     ...        0.000000
# 25%      2.000000    2.00000    2.000000    2.00000     ...        2.000000
# 50%      4.000000    3.50000    4.000000    4.00000     ...        4.000000
# 75%      8.000000    8.00000    8.000000    7.00000     ...        7.000000
# max     16.000000   18.00000   15.000000   18.00000     ...       20.000000
#
#               V12         V13         V14         V15         V16       V17  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.0000
# mean     5.140000    5.020000    4.870000    5.120000    4.680000    4.9700
# std      4.189983    3.926033    3.791684    4.025876    3.703343    3.9631
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.0000
# 25%      2.000000    2.000000    2.000000    2.000000    2.000000    2.0000
# 50%      4.000000    4.000000    4.000000    4.000000    4.000000    4.0000
# 75%      7.000000    7.000000    7.000000    7.000000    6.250000    7.0000
# max     19.000000   16.000000   15.000000   18.000000   16.000000   16.0000
#
#               V18         V19         V20
# count  100.000000  100.000000  100.000000
# mean     4.880000    5.170000    5.080000
# std      4.053381    4.476775    3.945794
# min      0.000000    0.000000    0.000000
# 25%      2.000000    2.000000    3.000000
# 50%      3.500000    3.000000    4.000000
# 75%      7.000000    8.000000    6.000000
# max     17.000000   23.000000   20.000000
#
# [8 rows x 21 columns]

# %%
# b)
plt.plot( expData['V1'] )

# %%
# c)
def plotScatters( df, cols ):
    totalCols = len(cols)
    plt.figure(figsize=(10,10))
    
    for i in range(totalCols):
        for j in range(totalCols):
            plt.subplot(5,5, i*5 + j + 1 )
            plt.scatter( df[cols[i]], df[cols[j]] )


plotScatters( expData, ['V1','V2','V3','V4','V5'] )

# %%
# d)
def computeCov(df):
    # remove first col
    df = np.matrix(df.as_matrix())[:,1:].T
    means = np.mean(df, axis=1)
    
    plt.figure(figsize=(10,10))

    centeredDf = df - means
    plt.subplot(1,2,1)
    cov = np.dot(centeredDf, centeredDf.T)
    plt.imshow(cov)
    plt.title("Manual Computed COV")
    
    plt.subplot(1,2,2)
    inbuiltCov = np.cov(centeredDf)
    plt.imshow(inbuiltCov)
    plt.title("Numpy COV")

    # output should be 20x20
    
computeCov(expData)

# %% [markdown]
# # 2 Plotting 3d

# %%
pcaData = pd.read_csv('pca-data-3d.txt')
pcaData.describe()
# Out:
#                 x           y           z
# count  500.000000  500.000000  500.000000
# mean     0.043555    0.091908   -0.059460
# std      0.965748    1.345888    2.094110
# min     -2.728321   -3.487070   -3.061867
# 25%     -0.658242   -0.840618   -2.045611
# 50%      0.055413    0.140944   -0.150139
# 75%      0.711236    0.985253    2.028950
# max      2.303785    3.836981    3.028818

# %%
plotScatters(pcaData, list(pcaData.columns))

# %%
def plot3D(df):
    fig = plt.figure()
    ax = plt.axes(projection='3d')
    ax.scatter( df.x, df.y, df.z )

plot3D(pcaData)

# %%
# plotScatters( pcaData, ['x','y'] )
plt.scatter( pcaData.x, pcaData.y )

# %%
# compute direction
def getDirectionVector(degree):
    theta = np.radians(degree)
    c, s = np.cos(theta), np.sin(theta)
    R = np.matrix('{} {}; {} {}'.format(c, -s, s, c))
    return np.dot(R, np.array([1,0])).A.flatten()

getDirectionVector(30)
# Out:
# array([ 0.8660254,  0.5      ])

# %%
def projectOnToDirection( df, degree ):
    df = np.matrix(df.as_matrix())[:,0:2].T

    v = getDirectionVector(degree).reshape(2,1)

    projected = np.dot(df.T, v)

    return projected
projectOnToDirection( pcaData, 30 )
# Out:
# matrix([[-0.0564749 ],
#         [-0.17245407],
#         [ 2.24820824],
#         [ 1.44302391],
#         [ 0.01024085],
#         [ 1.72012817],
#         [-1.1039202 ],
#         [-1.45688724],
#         [ 1.87858682],
#         [ 0.21611088],
#         [ 1.01238689],
#         [-0.41161637],
#         [ 0.62845982],
#         [ 0.21752667],
#         [-0.73170336],
#         [ 3.52110632],
#         [-0.4257255 ],
#         [ 1.58060699],
#         [ 0.23120003],
#         [-1.21531743],
#         [ 0.2046774 ],
#         [-0.13330019],
#         [-0.6158891 ],
#         [ 0.31992181],
#         [ 1.27099007],
#         [-1.75089479],
#         [ 0.51812083],
#         [ 1.1724111 ],
#         [ 1.02044499],
#         [-0.466608  ],
#         [-1.40693344],
#         [ 1.21116339],
#         [-2.0794033 ],
#         [ 0.3736707 ],
#         [ 1.24717465],
#         [-2.24550215],
#         [-0.8169067 ],
#         [-1.30725355],
#         [ 0.31403366],
#         [ 1.22910922],
#         [-2.46180179],
#         [ 0.16930854],
#         [-1.44803912],
#         [ 0.60485825],
#         [-0.52079701],
#         [-1.00422187],
#         [ 0.09978575],
#         [ 0.91816172],
#         [ 1.71169895],
#         [-2.80298737],
#         [ 0.57467439],
#         [-0.94464991],
#         [ 0.85366158],
#         [ 0.33381023],
#         [-0.17613712],
#         [-0.376456  ],
#         [-0.39591694],
#         [-1.74963851],
#         [-3.16338834],
#         [ 0.34877279],
#         [-0.80276614],
#         [-0.30708078],
#         [ 2.24619238],
#         [ 1.46401259],
#         [-0.32984719],
#         [ 0.03390627],
#         [-0.25866121],
#         [-0.53219022],
#         [-1.15650773],
#         [-2.78700012],
#         [ 0.66503661],
#         [ 0.12221242],
#         [ 2.68115687],
#         [-0.38925708],
#         [ 1.50485636],
#         [ 0.4580127 ],
#         [-0.44102364],
#         [-0.33946581],
#         [ 0.5499928 ],
#         [-0.93321194],
#         [-0.35886795],
#         [ 0.30232049],
#         [ 0.96473988],
#         [-0.0241009 ],
#         [ 2.04342259],
#         [ 1.85145677],
#         [ 1.03074658],
#         [ 0.73171182],
#         [-1.58381085],
#         [-0.23766883],
#         [ 2.24201574],
#         [-1.28561532],
#         [ 0.10474255],
#         [ 0.55391454],
#         [-0.64319246],
#         [-2.53890243],
#         [-2.06616892],
#         [ 2.42198197],
#         [ 1.95830951],
#         [ 1.43805236],
#         [-0.06634941],
#         [ 0.62410085],
#         [ 1.63690753],
#         [-2.31669332],
#         [ 0.18016631],
#         [-0.34781203],
#         [-0.29625809],
#         [-0.17455168],
#         [-0.07607004],
#         [ 0.59580963],
#         [-0.90772175],
#         [-0.87621823],
#         [-0.56389663],
#         [ 1.23640891],
#         [-0.92870724],
#         [ 1.45545593],
#         [-0.33215147],
#         [-1.67612685],
#         [ 2.00033689],
#         [ 2.26129176],
#         [ 0.83419877],
#         [-1.33882608],
#         [ 2.444734  ],
#         [-1.72619379],
#         [ 0.59647783],
#         [ 0.72234819],
#         [ 1.25631049],
#         [-0.11221651],
#         [-0.42752909],
#         [ 2.42689296],
#         [-0.23285852],
#         [ 0.52397279],
#         [ 0.3216937 ],
#         [ 1.02256324],
#         [-0.1308151 ],
#         [ 1.42115995],
#         [-3.16339863],
#         [ 0.58753729],
#         [-1.99696277],
#         [-0.37636199],
#         [ 0.1512204 ],
#         [ 1.02312785],
#         [-0.84569623],
#         [-0.96874919],
#         [ 1.64055734],
#         [ 2.04583967],
#         [ 1.11793585],
#         [ 1.13071506],
#         [-1.83383942],
#         [ 0.4963159 ],
#         [ 2.52724598],
#         [ 0.80090549],
#         [-0.24845634],
#         [-1.16094913],
#         [ 1.39862864],
#         [ 1.45579854],
#         [-1.51648431],
#         [ 2.37358512],
#         [ 1.6142502 ],
#         [ 1.8310353 ],
#         [ 1.63632075],
#         [ 1.52452049],
#         [-1.66363034],
#         [ 1.91411649],
#         [ 1.13837427],
#         [ 0.50329413],
#         [-1.39651461],
#         [ 0.7231536 ],
#         [-0.35188276],
#         [-1.21365116],
#         [ 2.36815704],
#         [ 1.33527491],
#         [-1.3348637 ],
#         [ 1.05444586],
#         [-1.47983927],
#         [ 0.92964809],
#         [-0.44260965],
#         [-0.16310007],
#         [ 2.25330848],
#         [-3.71722441],
#         [-1.37390277],
#         [ 0.24834892],
#         [-3.27704533],
#         [ 0.61430064],
#         [ 1.51846677],
#         [-1.43678139],
#         [-0.03834184],
#         [ 0.4812354 ],
#         [ 3.35023934],
#         [-0.71844272],
#         [ 1.31444263],
#         [-1.24787235],
#         [-0.68902632],
#         [ 0.53567597],
#         [ 0.7858017 ],
#         [-1.43376949],
#         [ 1.5762538 ],
#         [ 0.53113671],
#         [-1.22700115],
#         [ 0.80061735],
#         [-0.32146411],
#         [ 2.66296069],
#         [-0.71155612],
#         [-0.45348977],
#         [-2.09308139],
#         [-0.90467557],
#         [ 0.68776353],
#         [ 0.68345258],
#         [ 1.77452339],
#         [ 0.68553207],
#         [-1.22165122],
#         [ 0.91792462],
#         [-2.54241018],
#         [-1.10172642],
#         [-1.09437528],
#         [ 0.85023762],
#         [ 0.88014054],
#         [ 3.55007315],
#         [ 1.10611002],
#         [ 2.17765854],
#         [-0.22750482],
#         [-1.83068166],
#         [ 2.62616398],
#         [-1.35467425],
#         [ 1.06308468],
#         [ 0.58271299],
#         [-0.62151965],
#         [ 0.13117637],
#         [ 1.32788783],
#         [ 0.06630487],
#         [ 0.41758421],
#         [-1.19311153],
#         [ 0.0540044 ],
#         [-0.05591176],
#         [-1.93582361],
#         [-0.24717259],
#         [-2.04177426],
#         [-1.46923355],
#         [-0.43399006],
#         [ 1.54646136],
#         [ 0.23544043],
#         [ 0.12053489],
#         [ 0.48703028],
#         [-1.12326895],
#         [-1.11521678],
#         [-1.43362292],
#         [ 2.82211566],
#         [-1.94219726],
#         [-0.24301762],
#         [ 1.24146328],
#         [ 0.54510029],
#         [-0.4689886 ],
#         [-1.53807142],
#         [ 1.79057558],
#         [-1.18648746],
#         [ 1.43951386],
#         [-0.03545641],
#         [-0.41721789],
#         [ 2.56991751],
#         [ 0.46005454],
#         [-0.34611329],
#         [-1.45168436],
#         [ 1.42326958],
#         [ 1.53963444],
#         [ 0.2670821 ],
#         [ 1.74790714],
#         [-1.75161805],
#         [-1.31345953],
#         [ 1.70381379],
#         [-1.27483008],
#         [ 1.95204604],
#         [ 0.94133679],
#         [ 1.49345677],
#         [ 1.83100891],
#         [ 1.4390643 ],
#         [-0.67225707],
#         [ 0.52332147],
#         [ 0.11919997],
#         [-0.16346178],
#         [-0.82322644],
#         [-0.32415345],
#         [ 0.32052808],
#         [-0.87058371],
#         [ 0.81094669],
#         [ 0.96536921],
#         [-1.52281101],
#         [ 1.69232245],
#         [ 2.54355072],
#         [-2.23516038],
#         [ 0.3526054 ],
#         [-0.02049744],
#         [-2.39217131],
#         [-0.71609739],
#         [-1.56953097],
#         [ 1.83599918],
#         [ 1.05678054],
#         [ 1.18596392],
#         [ 0.4059409 ],
#         [ 1.84518708],
#         [-2.03867236],
#         [-1.1423076 ],
#         [ 0.88464487],
#         [-1.21888101],
#         [ 0.15043802],
#         [-3.40255137],
#         [-0.49245839],
#         [-2.02792246],
#         [-0.80012645],
#         [-1.6134732 ],
#         [ 0.6697426 ],
#         [-1.08794187],
#         [ 1.37898055],
#         [ 0.1083271 ],
#         [ 2.74066424],
#         [ 1.82266278],
#         [-0.25778866],
#         [-0.567475  ],
#         [ 0.41318941],
#         [-1.6573667 ],
#         [-1.39788791],
#         [ 0.42424477],
#         [-0.89933574],
#         [-1.71345933],
#         [ 1.28535643],
#         [-2.63430187],
#         [ 0.99948814],
#         [-0.39294045],
#         [-0.49479601],
#         [ 0.77571824],
#         [-1.61689492],
#         [-0.22813061],
#         [ 3.3932448 ],
#         [ 0.72791761],
#         [ 2.09909675],
#         [ 0.88495554],
#         [-2.51551051],
#         [ 0.07481304],
#         [ 2.83309589],
#         [ 0.69530945],
#         [ 1.88301875],
#         [-0.13874791],
#         [-0.46027124],
#         [ 1.32675552],
#         [ 3.61917989],
#         [-0.37408246],
#         [-0.75030326],
#         [ 1.40384566],
#         [-0.69217531],
#         [ 1.38975842],
#         [-0.24200859],
#         [-1.41627114],
#         [ 0.12496524],
#         [ 1.76736345],
#         [ 0.22049451],
#         [-3.34494238],
#         [ 1.0952125 ],
#         [-2.37168362],
#         [-2.78899594],
#         [-0.81806979],
#         [ 0.73226213],
#         [ 0.72747168],
#         [ 0.84989489],
#         [ 1.19817594],
#         [-0.06609866],
#         [-0.66521276],
#         [ 0.05923895],
#         [ 2.3641815 ],
#         [ 0.12235355],
#         [-0.64396296],
#         [ 2.80000633],
#         [ 0.6048592 ],
#         [ 1.7598324 ],
#         [-0.91939538],
#         [ 0.80627227],
#         [-3.32391858],
#         [-0.12428775],
#         [ 0.93710935],
#         [-1.01043167],
#         [ 0.02061382],
#         [-0.18564221],
#         [-0.68128208],
#         [ 1.07177876],
#         [-0.84298266],
#         [-1.44046705],
#         [ 1.43627439],
#         [-0.45534715],
#         [-1.21151249],
#         [-0.59919318],
#         [ 0.52270565],
#         [ 1.75923408],
#         [-0.50445305],
#         [ 0.90212403],
#         [ 0.0066409 ],
#         [ 0.98995939],
#         [ 0.2314449 ],
#         [-0.21035514],
#         [-0.38389554],
#         [ 2.04238433],
#         [-0.90194375],
#         [-3.83135765],
#         [-0.67114337],
#         [ 2.03469467],
#         [-1.34913281],
#         [-1.41852917],
#         [ 1.96428269],
#         [-0.45262169],
#         [ 0.66484646],
#         [ 0.32290771],
#         [-0.40979315],
#         [ 2.97717318],
#         [-1.02236886],
#         [ 1.24797109],
#         [ 0.63180823],
#         [-1.69086846],
#         [-0.00960752],
#         [ 1.56586929],
#         [-0.99446263],
#         [ 0.08434314],
#         [ 0.26696236],
#         [-1.27280308],
#         [ 2.10784928],
#         [-1.01452789],
#         [ 0.87314181],
#         [ 0.78285995],
#         [-0.91468814],
#         [ 1.3559304 ],
#         [ 0.01057041],
#         [ 0.63256889],
#         [-2.66483884],
#         [ 0.64698819],
#         [-1.20940906],
#         [-0.03936692],
#         [ 0.29924877],
#         [ 0.20921607],
#         [-2.57593578],
#         [-1.35873374],
#         [ 2.84057514],
#         [-2.37525847],
#         [-0.06684027],
#         [-0.25596931],
#         [-1.43948117],
#         [ 0.03385099],
#         [ 0.58735367],
#         [ 0.71684784],
#         [-0.12750181],
#         [ 2.06432162],
#         [-2.70233495],
#         [ 0.37101193],
#         [-0.67337276],
#         [ 0.08691647],
#         [-0.85858078],
#         [ 1.85987345],
#         [-0.40706979],
#         [-0.14414486],
#         [-0.62141215],
#         [-1.81143678],
#         [ 3.77289349],
#         [-1.35860675],
#         [-0.56185294],
#         [ 2.07402094],
#         [-1.76785823],
#         [-1.31338549],
#         [ 0.42660105],
#         [-0.805653  ],
#         [ 1.19314138],
#         [-1.23959564],
#         [ 0.03814279],
#         [ 0.55239949],
#         [ 1.22711576],
#         [-0.36037921],
#         [ 2.58163403],
#         [-1.4036242 ],
#         [-0.83739912],
#         [-1.50657972],
#         [ 2.29327526],
#         [-0.96129597],
#         [-0.03292569],
#         [-1.28492732],
#         [-1.16441959],
#         [-1.28927442],
#         [-0.03763372],
#         [ 0.85638631],
#         [-1.35417802],
#         [ 0.47790242],
#         [ 1.7175237 ],
#         [ 1.55803479],
#         [ 0.43496665],
#         [ 2.32172359],
#         [ 1.06900587],
#         [-1.02797716],
#         [ 0.29072215],
#         [ 1.64038651],
#         [-0.67592879],
#         [ 1.3614746 ],
#         [-0.01347854],
#         [-0.86887602],
#         [-0.0679303 ],
#         [-2.98440562],
#         [ 1.24899598],
#         [ 1.5382576 ]])

# %%
def plotAngleVariance( df, degrees ) :
    variances = []
    for d in degrees:
        projected = projectOnToDirection(df, d)
        v = np.var(projected)

        variances.append(v)

    plt.plot(degrees, variances )
    plt.xlabel('Degree')
    plt.ylabel('Variance')
plotAngleVariance( pcaData, np.arange(0,181,15))

# %% [markdown]
# # 3 Processing Image Data

# %%
natIMG = mpimg.imread('natIMG.jpg')
# original image
plt.imshow(natIMG)
plt.colorbar()

# %%
plt.imshow(natIMG, cmap='gray')
plt.colorbar()

# %%
def plotPatches(img, no_patches, cmap='gray'):
    size = 10
    shape = img.shape
    
    plt.figure(figsize=(20,20))

    for i in range(no_patches):
        x = np.random.randint(0, shape[0] - size )
        y = np.random.randint(0, shape[1] - size )
        p = img[x:x+size,y:y+size]
        plt.subplot(10,10,i+1)
        plt.imshow(p, cmap=cmap)
        plt.title( "%d,%d" %(x,y))
        plt.xticks([])
        plt.yticks([])
        
plotPatches(natIMG, 100)
